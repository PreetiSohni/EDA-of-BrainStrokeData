# %% [markdown]
# # Libraries required for EDA
# ## pandas
# ## numpy
# ## matplotlib
# ## seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Step 1 -- Importing data

# %%
df=pd.read_csv("/content/drive/MyDrive/Videos PPT/brain_stroke.csv")

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %% [markdown]
# # Step 2 -- Get Insight of data
# ## Basic EDA

# %%
df.shape
# Out:
# (4981, 11)

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
 df.groupby("work_type")["stroke"].count().reset_index()
# Out:
#        work_type  stroke
# 0       Govt_job     644
# 1        Private    2860
# 2  Self-employed     804
# 3       children     673

# %%
df["bmi"].unique()
# Out:
# array([36.6, 32.5, 34.4, 24. , 29. , 27.4, 22.8, 24.2, 29.7, 36.8, 27.3,
#        28.2, 30.9, 37.5, 25.8, 37.8, 22.4, 48.9, 26.6, 27.2, 23.5, 28.3,
#        44.2, 25.4, 22.2, 30.5, 26.5, 33.7, 23.1, 32. , 29.9, 23.9, 28.5,
#        26.4, 20.2, 33.6, 38.6, 39.2, 27.7, 31.4, 36.5, 33.2, 32.8, 40.4,
#        25.3, 30.2, 47.5, 20.3, 30. , 28.9, 28.1, 31.1, 21.7, 27. , 24.1,
#        45.9, 44.1, 22.9, 29.1, 32.3, 41.1, 25.6, 29.8, 26.3, 26.2, 29.4,
#        24.4, 28. , 28.8, 34.6, 19.4, 30.3, 41.5, 22.6, 27.1, 31.3, 31. ,
#        31.7, 35.8, 28.4, 20.1, 26.7, 38.7, 34.9, 25. , 23.8, 21.8, 27.5,
#        24.6, 32.9, 26.1, 31.9, 34.1, 36.9, 37.3, 45.7, 34.2, 23.6, 22.3,
#        37.1, 45. , 25.5, 30.8, 37.4, 34.5, 27.9, 29.5, 46. , 42.5, 35.5,
#        26.9, 45.5, 31.5, 33. , 23.4, 30.7, 20.5, 21.5, 40. , 28.6, 42.2,
#        29.6, 35.4, 16.9, 26.8, 39.3, 32.6, 35.9, 21.2, 42.4, 40.5, 36.7,
#        29.3, 19.6, 18. , 17.6, 17.7, 35. , 22. , 39.4, 19.7, 22.5, 25.2,
# ...

# %%
df.groupby("smoking_status")["hypertension"].mean().reset_index()
# Out:
#     smoking_status  hypertension
# 0          Unknown      0.033333
# 1  formerly smoked      0.132641
# 2     never smoked      0.121328
# 3           smokes      0.117268

# %%
df.groupby(["smoking_status","work_type"]).agg({"hypertension":"mean","avg_glucose_level":["min","max"]}).reset_index()
# Out:
#      smoking_status      work_type hypertension avg_glucose_level
#                                            mean               min     max
# 0           Unknown       Govt_job     0.025000             56.08  226.28
# 1           Unknown        Private     0.044944             55.26  260.85
# 2           Unknown  Self-employed     0.124183             55.23  230.68
# 3           Unknown       children     0.000000             55.34  219.81
# 4   formerly smoked       Govt_job     0.145038             55.27  255.17
# 5   formerly smoked        Private     0.117534             56.11  267.76
# 6   formerly smoked  Self-employed     0.171569             56.08  261.67
# 7   formerly smoked       children     0.000000             63.22  144.08
# 8      never smoked       Govt_job     0.116788             55.84  266.59
# 9      never smoked        Private     0.107083             55.12  267.60
# 10     never smoked  Self-employed     0.197531             55.46  251.60
# ...

# %%
df.sort_values(by=['bmi','avg_glucose_level'],ascending=[True,True]).head(20)
# Out:
#       gender    age  hypertension  heart_disease ever_married work_type  \
# 4223  Female   4.00             0              0           No  children
# 1776  Female  67.00             0              0          Yes   Private
# 2609  Female   8.00             0              0           No  children
# 3193    Male   0.56             0              0           No  children
# 3907  Female   3.00             0              0           No  children
# 1487  Female   0.08             0              0           No  children
# 3148    Male   0.24             0              0           No  children
# 3939  Female   3.00             0              0           No  children
# 2052    Male   2.00             0              0           No  children
# 2468    Male  61.00             0              0          Yes   Private
# 2682    Male  10.00             0              0           No  children
# 1474    Male   0.40             0              0           No  children
# ...

# %%
df.groupby(["gender","ever_married"]).agg({"avg_glucose_level":["min","max"]}).reset_index()
# Out:
#    gender ever_married avg_glucose_level
#                                      min     max
# 0  Female           No             55.12  266.59
# 1  Female          Yes             55.27  267.76
# 2    Male           No             55.25  256.74
# 3    Male          Yes             55.22  271.74

# %%
df.groupby(["gender","ever_married"]).agg({"avg_glucose_level":["min","max"]}).reset_index()
# Out:
#    gender ever_married avg_glucose_level
#                                      min     max
# 0  Female           No             55.12  266.59
# 1  Female          Yes             55.27  267.76
# 2    Male           No             55.25  256.74
# 3    Male          Yes             55.22  271.74

# %%
def fun(i):
    if i<=10:
        return "kid"
    elif i>10 and i<=20:
        return "teenager"
    else:
        return "adult"

# %%
df["age"]=df["age"].apply(fun)
df
# Out:
#       gender    age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  adult             0              1          Yes        Private
# 1       Male  adult             0              1          Yes        Private
# 2     Female  adult             0              0          Yes        Private
# 3     Female  adult             1              0          Yes  Self-employed
# 4       Male  adult             0              0          Yes        Private
# ...      ...    ...           ...            ...          ...            ...
# 4976    Male  adult             0              0           No        Private
# 4977    Male  adult             0              0          Yes        Private
# 4978  Female  adult             1              0          Yes       Govt_job
# 4979    Male  adult             0              0          Yes        Private
# 4980  Female  adult             1              0          Yes        Private
#
# ...

# %%
df.groupby(["age"])["hypertension","avg_glucose_level","bmi"].agg(["min","max"]).reset_index()
# Out:
# <ipython-input-44-15e412a0b1ed>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["age"])["hypertension","avg_glucose_level","bmi"].agg(["min","max"]).reset_index()
#         age hypertension     avg_glucose_level           bmi
#                      min max               min     max   min   max
# 0     adult            0   1             55.12  271.74  14.1  48.9
# 1       kid            0   0             55.34  206.25  14.0  35.2
# 2  teenager            0   1             55.25  233.71  14.3  48.8

# %%
df.groupby(["age","gender"])["stroke"].count().reset_index()
# Out:
#         age  gender  stroke
# 0     adult  Female    2410
# 1     adult    Male    1583
# 2       kid  Female     226
# 3       kid    Male     267
# 4  teenager  Female     271
# 5  teenager    Male     224
